# %%
import pandas as pd 
import wandb
api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("yushuang/fin.highlight")

# %%
run_result = []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    this_run_data = dict()
    this_run_data.update(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    this_run_data.update(
        {k: v for k,v in run.config.items()
          if not k.startswith('_')})

    # .name is the human-readable name of the run.
    this_run_data.update({'name': run.name})


    slot_to_remove = []
    for k, v in this_run_data.items():
        if type(v) not in [int, str, float]:
            slot_to_remove.append(k)
    for s in slot_to_remove:
        del this_run_data[s]
    run_result.append(this_run_data)

runs_df = pd.DataFrame(run_result)
runs_df['_timestamp'] = runs_df['_timestamp'].map(pd.to_datetime)
# runs_df.to_csv("project.csv")

# %%
columns_to_use = [
    'name',
    'metric_for_best_model',
    '_timestamp'
]
metrics_names = ['f1', 'disorder', 'auprc', 'r_precision']
for m in metrics_names:
    for col in runs_df.columns:
        if m in col:
            columns_to_use.append(col)

# %%
show_columns = ['name', 'metric_for_best_model', '_timestamp']
show_metric = 'f1'
for split in ['train', 'valid', 'test', 'expert']:
    show_columns.append(f'eval/{split}_{show_metric}')
show_columns
# Out:
# ['name',
#  'metric_for_best_model',
#  '_timestamp',
#  'eval/train_f1',
#  'eval/valid_f1',
#  'eval/test_f1',
#  'eval/expert_f1']

# %%
tmp = runs_df[show_columns].copy()
mbm_metrics = 'valid_f1'
tmp[tmp['metric_for_best_model'] == mbm_metrics]
# Out:
#                                     name metric_for_best_model  \
# 0                       mix_strict_loose              valid_f1
# 3                curriculum_strict_loose              valid_f1
# 9   iterate_agg_strict_to_loose_valid_f1              valid_f1
# 10  iterate_agg_strict_to_loose_valid_f1              valid_f1
# 11                         cnc_highlight              valid_f1
# 12                                strict              valid_f1
# 15                                 naive              valid_f1
# 18                                 loose              valid_f1
# 21                               complex              valid_f1
# 24                                 harsh              valid_f1
# 27                  iterate_strict-naive              valid_f1
# 28                  iterate_strict-naive              valid_f1
# 29               curriculum_strict-naive              valid_f1
# 30                  iterate_strict-naive              valid_f1
# 33                  iterate_strict-naive              valid_f1
# 36                  iterate_strict-loose              valid_f1
# 37                  iterate_strict-loose              valid_f1
# 38               curriculum_strict-loose              valid_f1
# 39                  iterate_strict-loose              valid_f1
# 42                  iterate_strict-loose              valid_f1
# 45                  iterate_naive-strict              valid_f1
# 46                  iterate_naive-strict              valid_f1
# 47               curriculum_naive-strict              valid_f1
# 48                  iterate_naive-strict              valid_f1
#
#                       _timestamp  eval/train_f1  eval/valid_f1  eval/test_f1  \
# 0  1970-01-01 00:00:01.743014620       0.514568       0.454851      0.393147
# 3  1970-01-01 00:00:01.743040385       0.500201       0.462212      0.383900
# 9  1970-01-01 00:00:01.743867170       0.412493       0.439620      0.383267
# 10 1970-01-01 00:00:01.743869357       0.727696       0.486064      0.400387
# 11 1970-01-01 00:00:01.744051086       0.151517       0.174897      0.145643
# 12 1970-01-01 00:00:01.744055511       0.409651       0.430525      0.351960
# 15 1970-01-01 00:00:01.744057950       0.692207       0.554229      0.456172
# 18 1970-01-01 00:00:01.744060804       0.870119       0.551087      0.462286
# 21 1970-01-01 00:00:01.744063284       0.265999       0.289659      0.261726
# 24 1970-01-01 00:00:01.744064856       0.293482       0.292234      0.240707
# 27 1970-01-01 00:00:01.744066819       0.414282       0.428510      0.363940
# 28 1970-01-01 00:00:01.744068576       0.453253       0.458084      0.382628
# 29 1970-01-01 00:00:01.744071749       0.415673       0.451094      0.344904
# 30 1970-01-01 00:00:01.744072671       0.409682       0.447129      0.363178
# 33 1970-01-01 00:00:01.744077141       0.411646       0.444552      0.369126
# 36 1970-01-01 00:00:01.744081150       0.416821       0.437322      0.389775
# 37 1970-01-01 00:00:01.744083247       0.702509       0.485146      0.390082
# 38 1970-01-01 00:00:01.744085596       0.463478       0.452197      0.367883
# 39 1970-01-01 00:00:01.744086596       0.418661       0.434350      0.366957
# 42 1970-01-01 00:00:01.744090810       0.408860       0.435368      0.372590
# 45 1970-01-01 00:00:01.744101398       0.689770       0.564173      0.464160
# 46 1970-01-01 00:00:01.744101828       0.232312       0.313736      0.244609
# 47 1970-01-01 00:00:01.744103623       0.375329       0.470931      0.381647
# 48 1970-01-01 00:00:01.744104831       0.720371       0.552335      0.430637
#
#     eval/expert_f1
# 0         0.311353
# 3         0.323507
# 9         0.364215
# 10        0.347688
# 11        0.134023
# 12        0.344976
# 15        0.382382
# 18        0.393719
# 21        0.235002
# 24        0.214033
# 27        0.359422
# 28        0.325260
# 29        0.315194
# 30        0.344095
# 33        0.359011
# 36        0.372992
# 37        0.341924
# 38        0.329868
# 39        0.357034
# 42        0.356061
# 45        0.399893
# 46        0.211035
# 47        0.327243
# 48        0.362263
